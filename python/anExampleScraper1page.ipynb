# %% [markdown]
# # An example scraper
#
# The code below can be copied and adapted to create your own scraper.
#
# The first part installs all the libraries. I've kept this separate to the other parts so that you don't have to install them every time you want to run the scraper itself.

# %%
#install the libraries 
#requests is a library for fetching webpages from a URL
import requests
#BeautifulSoup is a library for scraping webpages
from bs4 import BeautifulSoup
#the pandas library which is used to work with data - we call it 'pd' here so we have to type less!
import pandas as pd

# %%
#This is a full URL for testing
testurl = "https://www.officialcharts.com/charts/singles-chart/20171222/7501/"

#Create a dataframe to store the data we are about to scrape
#It has one column called 'title'
#We call this dataframe 'df'
df = pd.DataFrame(columns=["title"])

#Scrape the html at that url
html = requests.get(testurl)
# turn our HTML *content* into a BeautifulSoup object
soup = BeautifulSoup(html.content) 
#There are 100 recordings on the page
#The titles are all in <div class="title"> and then <a 
#This targets the contents of those html tags
titles = soup.select('div.title a')
#the results are always a list - we'll deal with that in a second

#before we grab the *text* of those titles, we need an empty list to store those
titletext = []

#now back to the list of title tags - we have to loop through it using a 'for' loop
for i in titles:
  #each item in the list is called i as it loops - let's print each item
  print(i)
  #this includes the tags, but we can attach .get_text() to extract just the text
  title = i.get_text()
  print(title)
  #Now we need to store it in that list using .append()
  titletext.append(title)

#once the loop has finished we've appended 100 items to the previously empty list
#we can now use that to create a column in a dataframe variable called 'df' 
df = pd.DataFrame({"titles": titletext})
df.head()
# Out:
# <a href="/search/singles/perfect/">PERFECT</a>
# PERFECT
# <a href="/search/singles/river/">RIVER</a>
# RIVER
# <a href="/search/singles/last-christmas/">LAST CHRISTMAS</a>
# LAST CHRISTMAS
# <a href="/search/singles/all-i-want-for-christmas-is-you/">ALL I WANT FOR CHRISTMAS IS YOU</a>
# ALL I WANT FOR CHRISTMAS IS YOU
# <a href="/search/singles/anywhere/">ANYWHERE</a>
# ANYWHERE
# <a href="/search/singles/man's-not-hot/">MAN'S NOT HOT</a>
# MAN'S NOT HOT
# <a href="/search/singles/fairytale-of-new-york/">FAIRYTALE OF NEW YORK</a>
# FAIRYTALE OF NEW YORK
# <a href="/search/singles/i-miss-you/">I MISS YOU</a>
# I MISS YOU
# <a href="/search/singles/dimelo/">DIMELO</a>
# DIMELO
# <a href="/search/singles/let-you-down/">LET YOU DOWN</a>
# LET YOU DOWN
# <a href="/search/singles/17/">17</a>
# 17
# <a href="/search/singles/do-they-know-it's-christmas/">DO THEY KNOW IT'S CHRISTMAS</a>
# DO THEY KNOW IT'S CHRISTMAS
# <a href="/search/singles/havana/">HAVANA</a>
# HAVANA
# <a href="/search/singles/rockin'-around-the-christmas-tree/">ROCKIN' AROUND THE CHRISTMAS TREE</a>
# ROCKIN' AROUND THE CHRISTMAS TREE
# <a href="/search/singles/merry-christmas-everyone/">MERRY CHRISTMAS EVERYONE</a>
# MERRY CHRISTMAS EVERYONE
# <a href="/search/singles/wolves/">WOLVES</a>
# WOLVES
# <a href="/search/singles/barking/">BARKING</a>
# BARKING
# <a href="/search/singles/step-into-christmas/">STEP INTO CHRISTMAS</a>
# STEP INTO CHRISTMAS
# <a href="/search/singles/in-your-head/">IN YOUR HEAD</a>
# IN YOUR HEAD
# <a href="/search/singles/driving-home-for-christmas/">DRIVING HOME FOR CHRISTMAS</a>
# DRIVING HOME FOR CHRISTMAS
# <a href="/search/singles/walk-on-water/">WALK ON WATER</a>
# WALK ON WATER
# <a href="/search/singles/it's-beginning-to-look-a-lot-like/">IT'S BEGINNING TO LOOK A LOT LIKE</a>
# IT'S BEGINNING TO LOOK A LOT LIKE
# <a href="/search/singles/i-wish-it-could-be-christmas-everyday/">I WISH IT COULD BE CHRISTMAS EVERYDAY</a>
# I WISH IT COULD BE CHRISTMAS EVERYDAY
# <a href="/search/singles/naked/">NAKED</a>
# NAKED
# <a href="/search/singles/rockstar/">ROCKSTAR</a>
# ROCKSTAR
# <a href="/search/singles/no-words/">NO WORDS</a>
# NO WORDS
# <a href="/search/singles/beautiful-trauma/">BEAUTIFUL TRAUMA</a>
# BEAUTIFUL TRAUMA
# <a href="/search/singles/i-know-you/">I KNOW YOU</a>
# I KNOW YOU
# <a href="/search/singles/merry-xmas-everybody/">MERRY XMAS EVERYBODY</a>
# MERRY XMAS EVERYBODY
# <a href="/search/singles/silence/">SILENCE</a>
# SILENCE
# <a href="/search/singles/tip-toe/">TIP TOE</a>
# TIP TOE
# <a href="/search/singles/santa-tell-me/">SANTA TELL ME</a>
# SANTA TELL ME
# <a href="/search/singles/blinded-by-your-grace---pt-2/">BLINDED BY YOUR GRACE - PT 2</a>
# BLINDED BY YOUR GRACE - PT 2
# <a href="/search/singles/new-rules/">NEW RULES</a>
# NEW RULES
# <a href="/search/singles/happy-xmas-(war-is-over)/">HAPPY XMAS (WAR IS OVER)</a>
# HAPPY XMAS (WAR IS OVER)
# <a href="/search/singles/one-more-sleep/">ONE MORE SLEEP</a>
# ONE MORE SLEEP
# <a href="/search/singles/it's-the-most-wonderful-time-of-the-year/">IT'S THE MOST WONDERFUL TIME OF THE YEAR</a>
# IT'S THE MOST WONDERFUL TIME OF THE YEAR
# <a href="/search/singles/wonderful-christmastime/">WONDERFUL CHRISTMASTIME</a>
# WONDERFUL CHRISTMASTIME
# <a href="/search/singles/decline/">DECLINE</a>
# DECLINE
# <a href="/search/singles/my-lover/">MY LOVER</a>
# MY LOVER
# <a href="/search/singles/white-christmas/">WHITE CHRISTMAS</a>
# WHITE CHRISTMAS
# <a href="/search/singles/christmas-lights/">CHRISTMAS LIGHTS</a>
# CHRISTMAS LIGHTS
# <a href="/search/singles/breathe/">BREATHE</a>
# BREATHE
# <a href="/search/singles/too-good-at-goodbyes/">TOO GOOD AT GOODBYES</a>
# TOO GOOD AT GOODBYES
# <a href="/search/singles/bouff-daddy/">BOUFF DADDY</a>
# BOUFF DADDY
# <a href="/search/singles/mary's-boy-child_slash_oh-my-lord/">MARY'S BOY CHILD/OH MY LORD</a>
# MARY'S BOY CHILD/OH MY LORD
# <a href="/search/singles/underneath-the-tree/">UNDERNEATH THE TREE</a>
# UNDERNEATH THE TREE
# <a href="/search/singles/holly-jolly-christmas/">HOLLY JOLLY CHRISTMAS</a>
# HOLLY JOLLY CHRISTMAS
# <a href="/search/singles/santa-baby/">SANTA BABY</a>
# SANTA BABY
# <a href="/search/singles/one-last-song/">ONE LAST SONG</a>
# ONE LAST SONG
# <a href="/search/singles/mistletoe/">MISTLETOE</a>
# MISTLETOE
# <a href="/search/singles/shape-of-you/">SHAPE OF YOU</a>
# SHAPE OF YOU
# <a href="/search/singles/him-_and_-i/">HIM &amp; I</a>
# HIM & I
# <a href="/search/singles/finders-keepers/">FINDERS KEEPERS</a>
# FINDERS KEEPERS
# <a href="/search/singles/what-about-us/">WHAT ABOUT US</a>
# WHAT ABOUT US
# <a href="/search/singles/symphony/">SYMPHONY</a>
# SYMPHONY
# <a href="/search/singles/reggaeton-lento-(remix)/">REGGAETON LENTO (REMIX)</a>
# REGGAETON LENTO (REMIX)
# <a href="/search/singles/how-long/">HOW LONG</a>
# HOW LONG
# <a href="/search/singles/dirty-sexy-money/">DIRTY SEXY MONEY</a>
# DIRTY SEXY MONEY
# <a href="/search/singles/young-dumb-_and_-broke/">YOUNG DUMB &amp; BROKE</a>
# YOUNG DUMB & BROKE
# <a href="/search/singles/never-be-the-same/">NEVER BE THE SAME</a>
# NEVER BE THE SAME
# <a href="/search/singles/cola/">COLA</a>
# COLA
# <a href="/search/singles/bedroom-floor/">BEDROOM FLOOR</a>
# BEDROOM FLOOR
# <a href="/search/singles/dusk-till-dawn/">DUSK TILL DAWN</a>
# DUSK TILL DAWN
# <a href="/search/singles/santa's-coming-for-us/">SANTA'S COMING FOR US</a>
# SANTA'S COMING FOR US
# <a href="/search/singles/bad/">BAD</a>
# BAD
# <a href="/search/singles/gucci-gang/">GUCCI GANG</a>
# GUCCI GANG
# <a href="/search/singles/i-fall-apart/">I FALL APART</a>
# I FALL APART
# <a href="/search/singles/golden-slumbers/">GOLDEN SLUMBERS</a>
# GOLDEN SLUMBERS
# <a href="/search/singles/feel-it-still/">FEEL IT STILL</a>
# FEEL IT STILL
# <a href="/search/singles/despacito-(remix)/">DESPACITO (REMIX)</a>
# DESPACITO (REMIX)
# <a href="/search/singles/lemon/">LEMON</a>
# LEMON
# <a href="/search/singles/unforgettable/">UNFORGETTABLE</a>
# UNFORGETTABLE
# <a href="/search/singles/hurtin'-me/">HURTIN' ME</a>
# HURTIN' ME
# <a href="/search/singles/lonely-together/">LONELY TOGETHER</a>
# LONELY TOGETHER
# <a href="/search/singles/let-me-go/">LET ME GO</a>
# LET ME GO
# <a href="/search/singles/gorgeous/">GORGEOUS</a>
# GORGEOUS
# <a href="/search/singles/bank-account/">BANK ACCOUNT</a>
# BANK ACCOUNT
# <a href="/search/singles/motor-sport/">MOTOR SPORT</a>
# MOTOR SPORT
# <a href="/search/singles/castle-on-the-hill/">CASTLE ON THE HILL</a>
# CASTLE ON THE HILL
# <a href="/search/singles/no-limit/">NO LIMIT</a>
# NO LIMIT
# <a href="/search/singles/ready-for-it/">READY FOR IT</a>
# READY FOR IT
# <a href="/search/singles/sucker-for-you/">SUCKER FOR YOU</a>
# SUCKER FOR YOU
# <a href="/search/singles/holy-mountain/">HOLY MOUNTAIN</a>
# HOLY MOUNTAIN
# <a href="/search/singles/2000-miles/">2000 MILES</a>
# 2000 MILES
# <a href="/search/singles/what-lovers-do/">WHAT LOVERS DO</a>
# WHAT LOVERS DO
# <a href="/search/singles/then/">THEN</a>
# THEN
# <a href="/search/singles/candy-paint/">CANDY PAINT</a>
# CANDY PAINT
# <a href="/search/singles/is-your-love-enough/">IS YOUR LOVE ENOUGH</a>
# IS YOUR LOVE ENOUGH
# <a href="/search/singles/for-those-about-to-rock-(we-salute-you)/">FOR THOSE ABOUT TO ROCK (WE SALUTE YOU)</a>
# FOR THOSE ABOUT TO ROCK (WE SALUTE YOU)
# <a href="/search/singles/stop-the-cavalry/">STOP THE CAVALRY</a>
# STOP THE CAVALRY
# <a href="/search/singles/bestie/">BESTIE</a>
# BESTIE
# <a href="/search/singles/yrf/">YRF</a>
# YRF
# <a href="/search/singles/streets-of-london/">STREETS OF LONDON</a>
# STREETS OF LONDON
# <a href="/search/singles/human/">HUMAN</a>
# HUMAN
# <a href="/search/singles/mi-gente/">MI GENTE</a>
# MI GENTE
# <a href="/search/singles/lonely-this-christmas/">LONELY THIS CHRISTMAS</a>
# LONELY THIS CHRISTMAS
# <a href="/search/singles/all-night/">ALL NIGHT</a>
# ALL NIGHT
# <a href="/search/singles/1-800-273-8255/">1-800-273-8255</a>
# 1-800-273-8255
# <a href="/search/singles/you-make-it-feel-like-christmas/">YOU MAKE IT FEEL LIKE CHRISTMAS</a>
# YOU MAKE IT FEEL LIKE CHRISTMAS
#                             titles
# 0                          PERFECT
# 1                            RIVER
# 2                   LAST CHRISTMAS
# 3  ALL I WANT FOR CHRISTMAS IS YOU
# 4                         ANYWHERE

# %%
#Once the loop has finished we can take a look at the data
print(df)
# Out:
#                              titles
# 0                           PERFECT
# 1                             RIVER
# 2                    LAST CHRISTMAS
# 3   ALL I WANT FOR CHRISTMAS IS YOU
# 4                          ANYWHERE
# ..                              ...
# 95                         MI GENTE
# 96            LONELY THIS CHRISTMAS
# 97                        ALL NIGHT
# 98                   1-800-273-8255
# 99  YOU MAKE IT FEEL LIKE CHRISTMAS
#
# [100 rows x 1 columns]

# %%
#And we can export it
df.to_csv("scrapeddata.csv")

# %% [markdown]
# ## How to adapt it
#
# You can use most of this code without having to change it. All you *need* to change is this line, which specifies what webpage you want to scrape:
#
# `testurl = "https://www.officialcharts.com/charts/singles-chart/20171222/7501/"`
#
# And this line, which specifies what you want to scrape from that page:
#
# `titles = soup.select('div.title a')`
#
# If you're scraping one type of information from one page, that will be enough.
#
# Specifically, you will need to change the URL (keeping the quotation marks), and the CSS selector `'div.title a'` (again, keeping the quotation marks).
#
# For the CSS selector you will need to identify the HTML in the page you are scraping, and the combination of tags that is being used.
#
# Some [reading around CSS selectors](https://www.w3schools.com/cssref/css_selectors.asp) will help you here, but a couple of useful things to know include:
#
# * A period `.` means `class="`
# * A hash `#` means `id="`
#
# So `'div.title a'` means `<div class="title"><a ...>` - or, in other words, anything on the page inside an `<a>` tag (a link) within a `<div class="title">` tag.
#
# The words used for variables (like "testurl" and "titles" above) may not be relevant to what you are scraping - but that doesn't matter, because those words are arbitrary. If you do decide to change them, make sure you change them *throughout* the code, or it will create an error.

# %% [markdown]
# ## Expanding from one column to multiple columns
#
# In the example scraper we scraped just one type of information (the titles), and created a dataframe with one column for 100 instances of that.
#
# We did that by extracting the text of each of the 100 instances, and adding that text to a list. Once the list was finished we created a dataframe using that list as the column.
#
# But what if we wanted more than one type of info?
#
# To do that we repeat what we did so that instead of creating a dataframe with one list as the column we use two or three or more lists as the columns.
#
# This means we will need to:
#
# * Grab the matches for the other two tags and store in two other lists
# * Create another two empty lists - one for each column we want to add
# * Loop through each list of tags, and extract the text contents, storing it in that empty list
# * Once we have those 3 lists of text, create a dataframe using those as columns
#
# Here's the code that does that.

# %%
#Create 3 lists that each selects the contents of different tags
titles = soup.select('div.title a')
artists = soup.select('div.artist a')
labels = soup.select('div.label-cat span')
#How long is each list?
listlength = len(titles)
print(listlength)

#create 3 empty lists for our columns - which we can fill in the loop
titlecol = []
artistcol = []
labelcol = []

#we loop through the titles grabbed
for i in titles:
  #each item in the list generated is called i as it loops
  print(i)
  #we access the item at that position in the list, and grab its text 
  title = i.get_text()
  #and add it to the relevant list
  titlecol.append(title)
#once this loop finishes we have 100 items

#now we loop through the artists grabbed
for i in artists:
  #each item in the list generated is called i as it loops
  print(i)
  #we access the item at that position in the list, and grab its text 
  artist = i.get_text()
  #and add it to the relevant list
  artistcol.append(artist)
#once this loop finishes we have a second list of 100 items

#finally we loop through the labels grabbed
for i in labels:
  #each item in the list generated is called i as it loops
  print(i)
  #we access the item at that position in the list, and grab its text 
  label = i.get_text()
  #and add it to the relevant list
  labelcol.append(label)
#now we should have 3 lists of 100 items each, which we can use to create a dataframe

# we name the 3 columns as strings, then name the list variable we want under that string
df3cols = pd.DataFrame({"title":titlecol, "artist": artistcol, "label": labelcol})
print(df3cols)
# Out:
# 100
# <a href="/search/singles/perfect/">PERFECT</a>
# <a href="/search/singles/river/">RIVER</a>
# <a href="/search/singles/last-christmas/">LAST CHRISTMAS</a>
# <a href="/search/singles/all-i-want-for-christmas-is-you/">ALL I WANT FOR CHRISTMAS IS YOU</a>
# <a href="/search/singles/anywhere/">ANYWHERE</a>
# <a href="/search/singles/man's-not-hot/">MAN'S NOT HOT</a>
# <a href="/search/singles/fairytale-of-new-york/">FAIRYTALE OF NEW YORK</a>
# <a href="/search/singles/i-miss-you/">I MISS YOU</a>
# <a href="/search/singles/dimelo/">DIMELO</a>
# <a href="/search/singles/let-you-down/">LET YOU DOWN</a>
# <a href="/search/singles/17/">17</a>
# <a href="/search/singles/do-they-know-it's-christmas/">DO THEY KNOW IT'S CHRISTMAS</a>
# <a href="/search/singles/havana/">HAVANA</a>
# <a href="/search/singles/rockin'-around-the-christmas-tree/">ROCKIN' AROUND THE CHRISTMAS TREE</a>
# <a href="/search/singles/merry-christmas-everyone/">MERRY CHRISTMAS EVERYONE</a>
# <a href="/search/singles/wolves/">WOLVES</a>
# <a href="/search/singles/barking/">BARKING</a>
# <a href="/search/singles/step-into-christmas/">STEP INTO CHRISTMAS</a>
# <a href="/search/singles/in-your-head/">IN YOUR HEAD</a>
# <a href="/search/singles/driving-home-for-christmas/">DRIVING HOME FOR CHRISTMAS</a>
# <a href="/search/singles/walk-on-water/">WALK ON WATER</a>
# <a href="/search/singles/it's-beginning-to-look-a-lot-like/">IT'S BEGINNING TO LOOK A LOT LIKE</a>
# <a href="/search/singles/i-wish-it-could-be-christmas-everyday/">I WISH IT COULD BE CHRISTMAS EVERYDAY</a>
# <a href="/search/singles/naked/">NAKED</a>
# <a href="/search/singles/rockstar/">ROCKSTAR</a>
# <a href="/search/singles/no-words/">NO WORDS</a>
# <a href="/search/singles/beautiful-trauma/">BEAUTIFUL TRAUMA</a>
# <a href="/search/singles/i-know-you/">I KNOW YOU</a>
# <a href="/search/singles/merry-xmas-everybody/">MERRY XMAS EVERYBODY</a>
# <a href="/search/singles/silence/">SILENCE</a>
# <a href="/search/singles/tip-toe/">TIP TOE</a>
# <a href="/search/singles/santa-tell-me/">SANTA TELL ME</a>
# <a href="/search/singles/blinded-by-your-grace---pt-2/">BLINDED BY YOUR GRACE - PT 2</a>
# <a href="/search/singles/new-rules/">NEW RULES</a>
# <a href="/search/singles/happy-xmas-(war-is-over)/">HAPPY XMAS (WAR IS OVER)</a>
# <a href="/search/singles/one-more-sleep/">ONE MORE SLEEP</a>
# <a href="/search/singles/it's-the-most-wonderful-time-of-the-year/">IT'S THE MOST WONDERFUL TIME OF THE YEAR</a>
# <a href="/search/singles/wonderful-christmastime/">WONDERFUL CHRISTMASTIME</a>
# <a href="/search/singles/decline/">DECLINE</a>
# <a href="/search/singles/my-lover/">MY LOVER</a>
# <a href="/search/singles/white-christmas/">WHITE CHRISTMAS</a>
# <a href="/search/singles/christmas-lights/">CHRISTMAS LIGHTS</a>
# <a href="/search/singles/breathe/">BREATHE</a>
# <a href="/search/singles/too-good-at-goodbyes/">TOO GOOD AT GOODBYES</a>
# <a href="/search/singles/bouff-daddy/">BOUFF DADDY</a>
# <a href="/search/singles/mary's-boy-child_slash_oh-my-lord/">MARY'S BOY CHILD/OH MY LORD</a>
# <a href="/search/singles/underneath-the-tree/">UNDERNEATH THE TREE</a>
# <a href="/search/singles/holly-jolly-christmas/">HOLLY JOLLY CHRISTMAS</a>
# <a href="/search/singles/santa-baby/">SANTA BABY</a>
# <a href="/search/singles/one-last-song/">ONE LAST SONG</a>
# <a href="/search/singles/mistletoe/">MISTLETOE</a>
# <a href="/search/singles/shape-of-you/">SHAPE OF YOU</a>
# <a href="/search/singles/him-_and_-i/">HIM &amp; I</a>
# <a href="/search/singles/finders-keepers/">FINDERS KEEPERS</a>
# <a href="/search/singles/what-about-us/">WHAT ABOUT US</a>
# <a href="/search/singles/symphony/">SYMPHONY</a>
# <a href="/search/singles/reggaeton-lento-(remix)/">REGGAETON LENTO (REMIX)</a>
# <a href="/search/singles/how-long/">HOW LONG</a>
# <a href="/search/singles/dirty-sexy-money/">DIRTY SEXY MONEY</a>
# <a href="/search/singles/young-dumb-_and_-broke/">YOUNG DUMB &amp; BROKE</a>
# <a href="/search/singles/never-be-the-same/">NEVER BE THE SAME</a>
# <a href="/search/singles/cola/">COLA</a>
# <a href="/search/singles/bedroom-floor/">BEDROOM FLOOR</a>
# <a href="/search/singles/dusk-till-dawn/">DUSK TILL DAWN</a>
# <a href="/search/singles/santa's-coming-for-us/">SANTA'S COMING FOR US</a>
# <a href="/search/singles/bad/">BAD</a>
# <a href="/search/singles/gucci-gang/">GUCCI GANG</a>
# <a href="/search/singles/i-fall-apart/">I FALL APART</a>
# <a href="/search/singles/golden-slumbers/">GOLDEN SLUMBERS</a>
# <a href="/search/singles/feel-it-still/">FEEL IT STILL</a>
# <a href="/search/singles/despacito-(remix)/">DESPACITO (REMIX)</a>
# <a href="/search/singles/lemon/">LEMON</a>
# <a href="/search/singles/unforgettable/">UNFORGETTABLE</a>
# <a href="/search/singles/hurtin'-me/">HURTIN' ME</a>
# <a href="/search/singles/lonely-together/">LONELY TOGETHER</a>
# <a href="/search/singles/let-me-go/">LET ME GO</a>
# <a href="/search/singles/gorgeous/">GORGEOUS</a>
# <a href="/search/singles/bank-account/">BANK ACCOUNT</a>
# <a href="/search/singles/motor-sport/">MOTOR SPORT</a>
# <a href="/search/singles/castle-on-the-hill/">CASTLE ON THE HILL</a>
# <a href="/search/singles/no-limit/">NO LIMIT</a>
# <a href="/search/singles/ready-for-it/">READY FOR IT</a>
# <a href="/search/singles/sucker-for-you/">SUCKER FOR YOU</a>
# <a href="/search/singles/holy-mountain/">HOLY MOUNTAIN</a>
# <a href="/search/singles/2000-miles/">2000 MILES</a>
# <a href="/search/singles/what-lovers-do/">WHAT LOVERS DO</a>
# <a href="/search/singles/then/">THEN</a>
# <a href="/search/singles/candy-paint/">CANDY PAINT</a>
# <a href="/search/singles/is-your-love-enough/">IS YOUR LOVE ENOUGH</a>
# <a href="/search/singles/for-those-about-to-rock-(we-salute-you)/">FOR THOSE ABOUT TO ROCK (WE SALUTE YOU)</a>
# <a href="/search/singles/stop-the-cavalry/">STOP THE CAVALRY</a>
# <a href="/search/singles/bestie/">BESTIE</a>
# <a href="/search/singles/yrf/">YRF</a>
# <a href="/search/singles/streets-of-london/">STREETS OF LONDON</a>
# <a href="/search/singles/human/">HUMAN</a>
# <a href="/search/singles/mi-gente/">MI GENTE</a>
# <a href="/search/singles/lonely-this-christmas/">LONELY THIS CHRISTMAS</a>
# <a href="/search/singles/all-night/">ALL NIGHT</a>
# <a href="/search/singles/1-800-273-8255/">1-800-273-8255</a>
# <a href="/search/singles/you-make-it-feel-like-christmas/">YOU MAKE IT FEEL LIKE CHRISTMAS</a>
# <a href="/artist/6692/ed-sheeran/">ED SHEERAN</a>
# <a href="/artist/52778/eminem-ft-ed-sheeran/">EMINEM FT ED SHEERAN</a>
# <a href="/artist/19823/wham/">WHAM</a>
# <a href="/artist/25943/mariah-carey/">MARIAH CAREY</a>
# <a href="/artist/7418/rita-ora/">RITA ORA</a>
# <a href="/artist/52279/big-shaq/">BIG SHAQ</a>
# <a href="/artist/20669/pogues-ft-kirsty-maccoll/">POGUES FT KIRSTY MACCOLL</a>
# <a href="/artist/52510/clean-bandit-ft-julia-michaels/">CLEAN BANDIT FT JULIA MICHAELS</a>
# <a href="/artist/52716/rak-su-ft-wyclef-naughty-boy/">RAK-SU FT WYCLEF/NAUGHTY BOY</a>
# <a href="/artist/49497/nf/">NF</a>
# <a href="/artist/2340/mk/">MK</a>
# <a href="/artist/16510/band-aid/">BAND AID</a>
# <a href="/artist/51993/camila-cabello-ft-young-thug/">CAMILA CABELLO FT YOUNG THUG</a>
# <a href="/artist/8197/brenda-lee/">BRENDA LEE</a>
# <a href="/artist/50482/shakin-stevens/">SHAKIN' STEVENS</a>
# <a href="/artist/52496/selena-gomez-and-marshmello/">SELENA GOMEZ &amp; MARSHMELLO</a>
# <a href="/artist/52721/ramz/">RAMZ</a>
# <a href="/artist/21478/elton-john/">ELTON JOHN</a>
# <a href="/artist/7507/eminem/">EMINEM</a>
# <a href="/artist/29468/chris-rea/">CHRIS REA</a>
# <a href="/artist/52610/eminem-ft-beyonce/">EMINEM FT BEYONCE</a>
# <a href="/artist/13969/michael-buble/">MICHAEL BUBLE</a>
# <a href="/artist/10742/wizzard/">WIZZARD</a>
# <a href="/artist/28623/james-arthur/">JAMES ARTHUR</a>
# <a href="/artist/52239/post-malone-ft-21-savage/">POST MALONE FT 21 SAVAGE</a>
# <a href="/artist/52565/dave-ft-mostack/">DAVE FT MOSTACK</a>
# <a href="/artist/7334/pink/">PINK</a>
# <a href="/artist/52683/craig-david-ft-bastille/">CRAIG DAVID FT BASTILLE</a>
# <a href="/artist/30945/slade/">SLADE</a>
# <a href="/artist/52034/marshmello-ft-khalid/">MARSHMELLO FT KHALID</a>
# <a href="/artist/52612/jason-derulo-ft-french-montana/">JASON DERULO FT FRENCH MONTANA</a>
# <a href="/artist/26221/ariana-grande/">ARIANA GRANDE</a>
# <a href="/artist/51137/stormzy-ft-mnek/">STORMZY FT MNEK</a>
# <a href="/artist/48638/dua-lipa/">DUA LIPA</a>
# <a href="/artist/14792/john-and-yoko-plastic-ono-band/">JOHN &amp; YOKO/PLASTIC ONO BAND</a>
# <a href="/artist/2060/leona-lewis/">LEONA LEWIS</a>
# <a href="/artist/4530/andy-williams/">ANDY WILLIAMS</a>
# <a href="/artist/18538/paul-mccartney/">PAUL MCCARTNEY</a>
# <a href="/artist/52598/raye-ft-mr-eazi/">RAYE FT MR EAZI</a>
# <a href="/artist/50712/not3s/">NOT3S</a>
# <a href="/artist/73/bing-crosby/">BING CROSBY</a>
# <a href="/artist/7620/coldplay/">COLDPLAY</a>
# <a href="/artist/52717/jax-jones-ft-ina-wroldsen/">JAX JONES FT INA WROLDSEN</a>
# <a href="/artist/21501/sam-smith/">SAM SMITH</a>
# <a href="/artist/48523/j-hus/">J HUS</a>
# <a href="/artist/15971/boney-m/">BONEY M</a>
# <a href="/artist/13611/kelly-clarkson/">KELLY CLARKSON</a>
# <a href="/artist/13969/michael-buble/">MICHAEL BUBLE</a>
# <a href="/artist/43484/kylie-minogue/">KYLIE MINOGUE</a>
# <a href="/artist/21501/sam-smith/">SAM SMITH</a>
# <a href="/artist/6002/justin-bieber/">JUSTIN BIEBER</a>
# <a href="/artist/6692/ed-sheeran/">ED SHEERAN</a>
# <a href="/artist/52718/g-eazy-and-halsey/">G-EAZY &amp; HALSEY</a>
# <a href="/artist/52027/mabel-ft-kojo-funds/">MABEL FT KOJO FUNDS</a>
# <a href="/artist/7334/pink/">PINK</a>
# <a href="/artist/51258/clean-bandit-ft-zara-larsson/">CLEAN BANDIT FT ZARA LARSSON</a>
# <a href="/artist/52080/cnco-and-little-mix/">CNCO &amp; LITTLE MIX</a>
# <a href="/artist/48109/charlie-puth/">CHARLIE PUTH</a>
# <a href="/artist/52566/guetta-afrojack-xcx-montana/">GUETTA/AFROJACK/XCX/MONTANA</a>
# <a href="/artist/51180/khalid/">KHALID</a>
# <a href="/artist/49330/camila-cabello/">CAMILA CABELLO</a>
# <a href="/artist/51997/camelphat-and-elderbrook/">CAMELPHAT &amp; ELDERBROOK</a>
# <a href="/artist/51626/liam-payne/">LIAM PAYNE</a>
# <a href="/artist/52205/zayn-ft-sia/">ZAYN FT SIA</a>
# <a href="/artist/9062/sia/">SIA</a>
# <a href="/artist/52684/steel-banglez-yungen-mostack/">STEEL BANGLEZ/YUNGEN/MOSTACK</a>
# <a href="/artist/52397/lil-pump/">LIL PUMP</a>
# <a href="/artist/48821/post-malone/">POST MALONE</a>
# <a href="/artist/9505/elbow/">ELBOW</a>
# <a href="/artist/51991/portugal-the-man/">PORTUGAL THE MAN</a>
# <a href="/artist/51560/luis-fonsi-daddy-yankee-bieber/">LUIS FONSI/DADDY YANKEE/BIEBER</a>
# <a href="/artist/52545/nerd-and-rihanna/">NERD &amp; RIHANNA</a>
# <a href="/artist/51378/french-montana-ft-swae-lee/">FRENCH MONTANA FT SWAE LEE</a>
# <a href="/artist/52026/stefflon-don-and-french-montana/">STEFFLON DON &amp; FRENCH MONTANA</a>
# <a href="/artist/52051/avicii-ft-rita-ora/">AVICII FT RITA ORA</a>
# <a href="/artist/52206/hailee-steinfeld-alesso-watt/">HAILEE STEINFELD/ALESSO/WATT</a>
# <a href="/artist/5387/taylor-swift/">TAYLOR SWIFT</a>
# <a href="/artist/50585/21-savage/">21 SAVAGE</a>
# <a href="/artist/52511/migos-nicki-minaj-cardi-b/">MIGOS/NICKI MINAJ/CARDI B</a>
# <a href="/artist/6692/ed-sheeran/">ED SHEERAN</a>
# <a href="/artist/52642/g-eazy-ft-asap-rocky-and-cardi-b/">G-EAZY FT ASAP ROCKY &amp; CARDI B</a>
# <a href="/artist/5387/taylor-swift/">TAYLOR SWIFT</a>
# <a href="/artist/50672/matt-terry/">MATT TERRY</a>
# <a href="/artist/7094/noel-gallaghers-high-flying/">NOEL GALLAGHER'S HIGH FLYING</a>
# <a href="/artist/17432/pretenders/">PRETENDERS</a>
# <a href="/artist/52160/maroon-5-ft-sza/">MAROON 5 FT SZA</a>
# <a href="/artist/48070/anne-marie/">ANNE-MARIE</a>
# <a href="/artist/48821/post-malone/">POST MALONE</a>
# <a href="/artist/7217/little-mix/">LITTLE MIX</a>
# <a href="/artist/16970/ac-dc/">AC/DC</a>
# <a href="/artist/18454/jona-lewie/">JONA LEWIE</a>
# <a href="/artist/51757/yungen-ft-yxng-bane/">YUNGEN FT YXNG BANE</a>
# <a href="/artist/52779/grm-daily/">GRM DAILY</a>
# <a href="/artist/52744/ralph-mctell-crisis-chr-lennox/">RALPH MCTELL/CRISIS CHR/LENNOX</a>
# <a href="/artist/49947/ragnbone-man/">RAG'N'BONE MAN</a>
# <a href="/artist/51899/j-balvin-willy-william/">J BALVIN/WILLY WILLIAM</a>
# <a href="/artist/14800/mud/">MUD</a>
# <a href="/artist/52711/big-boi-ft-lunchmoney-lewis/">BIG BOI FT LUNCHMONEY LEWIS</a>
# <a href="/artist/51530/logic-alessia-cara-khalid/">LOGIC/ALESSIA CARA/KHALID</a>
# <a href="/artist/52745/gwen-stefani-ft-blake-shelton/">GWEN STEFANI FT BLAKE SHELTON</a>
# <span class="label">ASYLUM</span>
# <span class="label">INTERSCOPE</span>
# <span class="label">RCA</span>
# <span class="label">COLUMBIA</span>
# <span class="label">ATLANTIC</span>
# <span class="label">ISLAND</span>
# <span class="label">WARNER BROS</span>
# <span class="label">ATLANTIC/POLYDOR/REPUBLIC</span>
# <span class="label">SYCO MUSIC</span>
# <span class="label">EMI</span>
# <span class="label">COLUMBIA</span>
# <span class="label">MERCURY</span>
# <span class="label">EPIC/SYCO MUSIC</span>
# <span class="label">MCA</span>
# <span class="label">RCA</span>
# <span class="label">INTERSCOPE</span>
# <span class="label">POLYDOR</span>
# <span class="label">MERCURY</span>
# <span class="label">INTERSCOPE</span>
# <span class="label">WARNER BROS</span>
# <span class="label">INTERSCOPE</span>
# <span class="label">REPRISE</span>
# <span class="label">EMI</span>
# <span class="label">SYCO MUSIC</span>
# <span class="label">REPUBLIC RECORDS</span>
# <span class="label">DAVE</span>
# <span class="label">RCA</span>
# <span class="label">SPEAKERBOX RECORDINGS</span>
# <span class="label">BMG</span>
# <span class="label">MINISTRY OF SOUND</span>
# <span class="label">WARNER BROS</span>
# <span class="label">REPUBLIC RECORDS</span>
# <span class="label">MERKY</span>
# <span class="label">WARNER BROS</span>
# <span class="label">APPLE CORPS</span>
# <span class="label">SYCO MUSIC</span>
# <span class="label">SONY MUSIC</span>
# <span class="label">PARLOPHONE</span>
# <span class="label">POLYDOR</span>
# <span class="label">RELENTLESS</span>
# <span class="label">SPECTRUM MUSIC</span>
# <span class="label">PARLOPHONE</span>
# <span class="label">POLYDOR</span>
# <span class="label">CAPITOL</span>
# <span class="label">BLACK BUTTER</span>
# <span class="label">SONY MUSIC</span>
# <span class="label">RCA</span>
# <span class="label">REPRISE</span>
# <span class="label">PARLOPHONE</span>
# <span class="label">CAPITOL</span>
# <span class="label">DEF JAM</span>
# <span class="label">ASYLUM</span>
# <span class="label">RCA</span>
# <span class="label">POLYDOR</span>
# <span class="label">RCA</span>
# <span class="label">ATLANTIC</span>
# <span class="label">SYCO MUSIC</span>
# <span class="label">ATLANTIC</span>
# <span class="label">PARLOPHONE</span>
# <span class="label">RIGHT HAND MUSIC</span>
# <span class="label">EPIC/SYCO MUSIC</span>
# <span class="label">DEFECTED</span>
# <span class="label">CAPITOL</span>
# <span class="label">RCA</span>
# <span class="label">ATLANTIC/MONKEY PUZZLE</span>
# <span class="label">WARNER BROS</span>
# <span class="label">WARNER BROS</span>
# <span class="label">REPUBLIC RECORDS</span>
# <span class="label">POLYDOR</span>
# <span class="label">ATLANTIC</span>
# <span class="label">DEF JAM/RBMG/REPUBLIC/UMLE</span>
# <span class="label">RCA</span>
# <span class="label">BAD BOY/EPIC</span>
# <span class="label">POLYDOR</span>
# <span class="label">POSITIVA</span>
# <span class="label">REPUBLIC RECORDS</span>
# <span class="label">EMI</span>
# <span class="label">EPIC/SLAUGHTER GANG</span>
# <span class="label">MOTOWN/QUALITY CONTROL</span>
# <span class="label">ASYLUM</span>
# <span class="label">BPG/RCA/RVG</span>
# <span class="label">EMI</span>
# <span class="label">RCA</span>
# <span class="label">SOUR MASH</span>
# <span class="label">RHINO</span>
# <span class="label">INTERSCOPE</span>
# <span class="label">EAST WEST</span>
# <span class="label">ATLANTIC</span>
# <span class="label">SYCO MUSIC</span>
# <span class="label">COLUMBIA</span>
# <span class="label">STIFF</span>
# <span class="label">RCA</span>
# <span class="label">PARLOPHONE</span>
# <span class="label">MVKA</span>
# <span class="label">BEST LAID PLANS/COLUMBIA</span>
# <span class="label">BLUE WRASSE</span>
# <span class="label">EMI</span>
# <span class="label">EPIC</span>
# <span class="label">VIRGIN</span>
# <span class="label">INTERSCOPE</span>
#                               title                         artist  \
# 0                           PERFECT                     ED SHEERAN
# 1                             RIVER           EMINEM FT ED SHEERAN
# 2                    LAST CHRISTMAS                           WHAM
# 3   ALL I WANT FOR CHRISTMAS IS YOU                   MARIAH CAREY
# 4                          ANYWHERE                       RITA ORA
# ..                              ...                            ...
# 95                         MI GENTE         J BALVIN/WILLY WILLIAM
# 96            LONELY THIS CHRISTMAS                            MUD
# 97                        ALL NIGHT    BIG BOI FT LUNCHMONEY LEWIS
# 98                   1-800-273-8255      LOGIC/ALESSIA CARA/KHALID
# 99  YOU MAKE IT FEEL LIKE CHRISTMAS  GWEN STEFANI FT BLAKE SHELTON
#
#           label
# 0        ASYLUM
# 1    INTERSCOPE
# 2           RCA
# 3      COLUMBIA
# 4      ATLANTIC
# ..          ...
# 95  BLUE WRASSE
# 96          EMI
# 97         EPIC
# 98       VIRGIN
# 99   INTERSCOPE
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Bonus tip: scraping multiple pieces of information with `range` and indexes
#
# Another way to scrape multiple selectors one way to do that is to use indexes to loop through them. I'll explain what I mean...
#
# In the chart scraped above, there are 100 songs listed. When we grab different pieces of information with selectors we end up with 100 titles, 100 artists, 100 positions, and so on.
#
# At the moment it loops through the titles like this:
#
# ```python
# for i in titles:
#   title = i.get_text()
# ```
#
# However, we could instead loop through a range of numbers:
#
# ```python
# for i in range(0,100):
#   title = titles[i].get_text()
# ```
#
# This means that each time we are accessing a different index position in that list `titles`: the first time the loop runs it grabs `titles[0]`; the second time `titles[1]` and so on.
#
# The range stops at index `99`, which is fine because that means position 100.
#
# Using this approach means we don't need 3 different loops - but can loop through all 3 lists at once in a single loop. The difference is that we will be looping through *numbers*, and using each number to access the item at that *position* in all 3 lists.
#
# This is how it works:
#
# We loop through numbers from 0 to 99. The first time we loop the number is 0, and we use this to say "get the item at position 0 in the list 'titles', and position 0 in the list 'artists' and position 0 in the list 'labels'"
#
# We've now grabbed 3 items from 3 lists!
#
# Here's the code:

# %%
#Change our dataframe to have 3 columns
#We call this dataframe 'df'
df = pd.DataFrame(columns=["title","artist","label"])

#Create 3 lists that each selects the contents of different tags
titles = soup.select('div.title a')
artists = soup.select('div.artist a')
labels = soup.select('div.label-cat span')
#How long is each list?
listlength = len(titles)
print(listlength)
#we loop through a range of numbers rather than the lists themselves
for i in range(0,listlength):
  #each number in the list generated is called i as it loops
  print(i)
  #we access the item at that position in the list, and grab its text contents
  title = titles[i].get_text()
  artist = artists[i].get_text()
  label = labels[i].get_text()
  print(title, artist, label)
  #Now we need to store it in that variable called 'df' 
  df = df.append({
    "title" : title,
    "artist" : artist,
    "label" : label
    }, ignore_index=True)

print(df)
# Out:
# 100
# 0
# PERFECT ED SHEERAN ASYLUM
# 1
# RIVER EMINEM FT ED SHEERAN INTERSCOPE
# 2
# LAST CHRISTMAS WHAM RCA
# 3
# ALL I WANT FOR CHRISTMAS IS YOU MARIAH CAREY COLUMBIA
# 4
# ANYWHERE RITA ORA ATLANTIC
# 5
# MAN'S NOT HOT BIG SHAQ ISLAND
# 6
# FAIRYTALE OF NEW YORK POGUES FT KIRSTY MACCOLL WARNER BROS
# 7
# I MISS YOU CLEAN BANDIT FT JULIA MICHAELS ATLANTIC/POLYDOR/REPUBLIC
# 8
# DIMELO RAK-SU FT WYCLEF/NAUGHTY BOY SYCO MUSIC
# 9
# LET YOU DOWN NF EMI
# 10
# 17 MK COLUMBIA
# 11
# DO THEY KNOW IT'S CHRISTMAS BAND AID MERCURY
# 12
# HAVANA CAMILA CABELLO FT YOUNG THUG EPIC/SYCO MUSIC
# 13
# ROCKIN' AROUND THE CHRISTMAS TREE BRENDA LEE MCA
# 14
# MERRY CHRISTMAS EVERYONE SHAKIN' STEVENS RCA
# 15
# WOLVES SELENA GOMEZ & MARSHMELLO INTERSCOPE
# 16
# BARKING RAMZ POLYDOR
# 17
# STEP INTO CHRISTMAS ELTON JOHN MERCURY
# 18
# IN YOUR HEAD EMINEM INTERSCOPE
# 19
# DRIVING HOME FOR CHRISTMAS CHRIS REA WARNER BROS
# 20
# WALK ON WATER EMINEM FT BEYONCE INTERSCOPE
# 21
# IT'S BEGINNING TO LOOK A LOT LIKE MICHAEL BUBLE REPRISE
# 22
# I WISH IT COULD BE CHRISTMAS EVERYDAY WIZZARD EMI
# 23
# NAKED JAMES ARTHUR SYCO MUSIC
# 24
# ROCKSTAR POST MALONE FT 21 SAVAGE REPUBLIC RECORDS
# 25
# NO WORDS DAVE FT MOSTACK DAVE
# 26
# BEAUTIFUL TRAUMA PINK RCA
# 27
# I KNOW YOU CRAIG DAVID FT BASTILLE SPEAKERBOX RECORDINGS
# 28
# MERRY XMAS EVERYBODY SLADE BMG
# 29
# SILENCE MARSHMELLO FT KHALID MINISTRY OF SOUND
# 30
# TIP TOE JASON DERULO FT FRENCH MONTANA WARNER BROS
# 31
# SANTA TELL ME ARIANA GRANDE REPUBLIC RECORDS
# 32
# BLINDED BY YOUR GRACE - PT 2 STORMZY FT MNEK MERKY
# 33
# NEW RULES DUA LIPA WARNER BROS
# 34
# HAPPY XMAS (WAR IS OVER) JOHN & YOKO/PLASTIC ONO BAND APPLE CORPS
# 35
# ONE MORE SLEEP LEONA LEWIS SYCO MUSIC
# 36
# IT'S THE MOST WONDERFUL TIME OF THE YEAR ANDY WILLIAMS SONY MUSIC
# 37
# WONDERFUL CHRISTMASTIME PAUL MCCARTNEY PARLOPHONE
# 38
# DECLINE RAYE FT MR EAZI POLYDOR
# 39
# MY LOVER NOT3S RELENTLESS
# 40
# WHITE CHRISTMAS BING CROSBY SPECTRUM MUSIC
# 41
# CHRISTMAS LIGHTS COLDPLAY PARLOPHONE
# 42
# BREATHE JAX JONES FT INA WROLDSEN POLYDOR
# 43
# TOO GOOD AT GOODBYES SAM SMITH CAPITOL
# 44
# BOUFF DADDY J HUS BLACK BUTTER
# 45
# MARY'S BOY CHILD/OH MY LORD BONEY M SONY MUSIC
# 46
# UNDERNEATH THE TREE KELLY CLARKSON RCA
# 47
# HOLLY JOLLY CHRISTMAS MICHAEL BUBLE REPRISE
# 48
# SANTA BABY KYLIE MINOGUE PARLOPHONE
# 49
# ONE LAST SONG SAM SMITH CAPITOL
# 50
# MISTLETOE JUSTIN BIEBER DEF JAM
# 51
# SHAPE OF YOU ED SHEERAN ASYLUM
# 52
# HIM & I G-EAZY & HALSEY RCA
# 53
# FINDERS KEEPERS MABEL FT KOJO FUNDS POLYDOR
# 54
# WHAT ABOUT US PINK RCA
# 55
# SYMPHONY CLEAN BANDIT FT ZARA LARSSON ATLANTIC
# 56
# REGGAETON LENTO (REMIX) CNCO & LITTLE MIX SYCO MUSIC
# 57
# HOW LONG CHARLIE PUTH ATLANTIC
# 58
# DIRTY SEXY MONEY GUETTA/AFROJACK/XCX/MONTANA PARLOPHONE
# 59
# YOUNG DUMB & BROKE KHALID RIGHT HAND MUSIC
# 60
# NEVER BE THE SAME CAMILA CABELLO EPIC/SYCO MUSIC
# 61
# COLA CAMELPHAT & ELDERBROOK DEFECTED
# 62
# BEDROOM FLOOR LIAM PAYNE CAPITOL
# 63
# DUSK TILL DAWN ZAYN FT SIA RCA
# 64
# SANTA'S COMING FOR US SIA ATLANTIC/MONKEY PUZZLE
# 65
# BAD STEEL BANGLEZ/YUNGEN/MOSTACK WARNER BROS
# 66
# GUCCI GANG LIL PUMP WARNER BROS
# 67
# I FALL APART POST MALONE REPUBLIC RECORDS
# 68
# GOLDEN SLUMBERS ELBOW POLYDOR
# 69
# FEEL IT STILL PORTUGAL THE MAN ATLANTIC
# 70
# DESPACITO (REMIX) LUIS FONSI/DADDY YANKEE/BIEBER DEF JAM/RBMG/REPUBLIC/UMLE
# 71
# LEMON NERD & RIHANNA RCA
# 72
# UNFORGETTABLE FRENCH MONTANA FT SWAE LEE BAD BOY/EPIC
# 73
# HURTIN' ME STEFFLON DON & FRENCH MONTANA POLYDOR
# 74
# LONELY TOGETHER AVICII FT RITA ORA POSITIVA
# 75
# LET ME GO HAILEE STEINFELD/ALESSO/WATT REPUBLIC RECORDS
# 76
# GORGEOUS TAYLOR SWIFT EMI
# 77
# BANK ACCOUNT 21 SAVAGE EPIC/SLAUGHTER GANG
# 78
# MOTOR SPORT MIGOS/NICKI MINAJ/CARDI B MOTOWN/QUALITY CONTROL
# 79
# CASTLE ON THE HILL ED SHEERAN ASYLUM
# 80
# NO LIMIT G-EAZY FT ASAP ROCKY & CARDI B BPG/RCA/RVG
# 81
# READY FOR IT TAYLOR SWIFT EMI
# 82
# SUCKER FOR YOU MATT TERRY RCA
# 83
# HOLY MOUNTAIN NOEL GALLAGHER'S HIGH FLYING SOUR MASH
# 84
# 2000 MILES PRETENDERS RHINO
# 85
# WHAT LOVERS DO MAROON 5 FT SZA INTERSCOPE
# 86
# THEN ANNE-MARIE EAST WEST
# 87
# CANDY PAINT POST MALONE ATLANTIC
# 88
# IS YOUR LOVE ENOUGH LITTLE MIX SYCO MUSIC
# 89
# FOR THOSE ABOUT TO ROCK (WE SALUTE YOU) AC/DC COLUMBIA
# 90
# STOP THE CAVALRY JONA LEWIE STIFF
# 91
# BESTIE YUNGEN FT YXNG BANE RCA
# 92
# YRF GRM DAILY PARLOPHONE
# 93
# STREETS OF LONDON RALPH MCTELL/CRISIS CHR/LENNOX MVKA
# 94
# HUMAN RAG'N'BONE MAN BEST LAID PLANS/COLUMBIA
# 95
# MI GENTE J BALVIN/WILLY WILLIAM BLUE WRASSE
# 96
# LONELY THIS CHRISTMAS MUD EMI
# 97
# ALL NIGHT BIG BOI FT LUNCHMONEY LEWIS EPIC
# 98
# 1-800-273-8255 LOGIC/ALESSIA CARA/KHALID VIRGIN
# 99
# YOU MAKE IT FEEL LIKE CHRISTMAS GWEN STEFANI FT BLAKE SHELTON INTERSCOPE
#                               title                         artist  \
# 0                           PERFECT                     ED SHEERAN
# 1                             RIVER           EMINEM FT ED SHEERAN
# 2                    LAST CHRISTMAS                           WHAM
# 3   ALL I WANT FOR CHRISTMAS IS YOU                   MARIAH CAREY
# 4                          ANYWHERE                       RITA ORA
# ..                              ...                            ...
# 95                         MI GENTE         J BALVIN/WILLY WILLIAM
# 96            LONELY THIS CHRISTMAS                            MUD
# 97                        ALL NIGHT    BIG BOI FT LUNCHMONEY LEWIS
# 98                   1-800-273-8255      LOGIC/ALESSIA CARA/KHALID
# 99  YOU MAKE IT FEEL LIKE CHRISTMAS  GWEN STEFANI FT BLAKE SHELTON
#
#           label
# 0        ASYLUM
# 1    INTERSCOPE
# 2           RCA
# 3      COLUMBIA
# 4      ATLANTIC
# ..          ...
# 95  BLUE WRASSE
# 96          EMI
# 97         EPIC
# 98       VIRGIN
# 99   INTERSCOPE
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Scraping multiple pages
#
# So far we've only scraped one page. To scrape more than one page we just extend the process using another loop.
#
# To do this we need a list of URLs to repeat the scraper on. The structure will look something like this:
#
# * Create dataframe
# * Create list of URLs
# * For each URL, run scraping code and append results to dataframe
#
# Creating the list of URLs might be done in one of the following ways:
#
# * Scraping another page: for example you might scrape a search results page to get that list of URLs, and then loop throgh those.
# * Following 'next' links from page to page: the charts page, for example, has a 'next' link which can be identified using the same techniques (cssselect) and then used as the URL to scrape
# * Generating URLs that follow a pattern: this might be sequential numbering, or it might be using codes that you can find elsewhere and loop through.

# %% [markdown]
# ## Generating URLs for a scraper to loop through
#
# Alternatively you might *generate* the URLs: for example, if they end in a number that goes up by 1 each time you can use `range` to generate that list of numbers and add them to the URL using `+`.
#
# However, you cannot mix numbers and strings, so you need to convert the numbers to a string as you do this. Here's an example:

# %%
#Create the basic URL that appears before the number
baseurl = "http://mypage.com?page="
#Create a list of numbers to put on the end
pagenums = range(1,11)
#Now generate the URLs by looping through the list and adding it to the URL
for i in pagenums:
  #Combine the two - 
  #this will generate an error because we are trying to combine a string and a number
  fullurl = baseurl+i
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-fe2fd370c033> in <module>()
#       6   #Combine the two -
#       7   #this will generate an error because we are trying to combine a string and a number
# ----> 8   fullurl = baseurl+i
#
# TypeError: must be str, not int

# %% [markdown]
# ## Tip: converting numbers into strings
#
# You can see the error `must be str, not int` - in other words the second part must be a string not an integer.
#
# To fix that you can use the `str()` function, which will convert a number into a string.

# %%
#Create the basic URL that appears before the number
baseurl = "http://mypage.com?page="
#Create a list of numbers to put on the end
pagenums = range(1,11)
#Now generate the URLs by looping through the list and adding it to the URL
for i in pagenums:
  #Convert i to a string
  i = str(i)
  #Combine the two
  fullurl = baseurl+i
  #print it
  print(fullurl)
# Out:
# http://mypage.com?page=1
# http://mypage.com?page=2
# http://mypage.com?page=3
# http://mypage.com?page=4
# http://mypage.com?page=5
# http://mypage.com?page=6
# http://mypage.com?page=7
# http://mypage.com?page=8
# http://mypage.com?page=9
# http://mypage.com?page=10
